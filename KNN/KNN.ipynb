# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.datasets  import load_wine

# %%
data = load_wine()

# %%
x = data.data
y = data.target

# %%
print(data.data.shape)
print(data.target_names)
# Out:
# (178, 13)
# ['class_0' 'class_1' 'class_2']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 2)

# %%
x_train.shape
# Out:
# (142, 13)

# %%
x_test.shape
# Out:
# (36, 13)

# %%
scores = []
for i in range(1,16):
    
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(x_train,y_train)
    y_pred = knn.predict(x_test)
    Accuracy=accuracy_score(y_test,y_pred)
    scores.append(Accuracy)
    print(f'for k : {i} , accuracy score:{Accuracy}')
# Out:
# for k : 1 , accuracy score:0.7222222222222222
# for k : 2 , accuracy score:0.7222222222222222
# for k : 3 , accuracy score:0.7777777777777778
# for k : 4 , accuracy score:0.75
# for k : 5 , accuracy score:0.75
# for k : 6 , accuracy score:0.75
# for k : 7 , accuracy score:0.75
# for k : 8 , accuracy score:0.8055555555555556
# for k : 9 , accuracy score:0.8055555555555556
# for k : 10 , accuracy score:0.8055555555555556
# for k : 11 , accuracy score:0.7777777777777778
# for k : 12 , accuracy score:0.8333333333333334
# for k : 13 , accuracy score:0.8055555555555556
# for k : 14 , accuracy score:0.8333333333333334
# for k : 15 , accuracy score:0.8611111111111112

# %%
import matplotlib.pyplot as plt

plt.plot(range(1,16),scores)

# %%
plot_decision_boundaries(15, X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plot_decision_boundaries(15, X, y)
#
# NameError: name 'plot_decision_boundaries' is not defined
