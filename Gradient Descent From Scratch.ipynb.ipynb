# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

# %%
X,y = make_regression(n_samples=10,n_features= 1,n_informative=1,noise=80,random_state=30)

# %%
plt.scatter(X,y)

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
#m in y = mx+b
lr.coef_
# Out:
# array([30.9241206])

# %%
#b in y= mx+b
lr.intercept_
# Out:
# 5.010778671635459

# %%
plt.scatter(X,y)
plt.plot(X,lr.predict(X),color='red')
plt.show()

# %%
#Lets apply Gradient Descent assuming slope is constant m = 78.35
# and let's assume the starting value for intercept b = 0
b = 0
y_pred = (( 30.92 * X )+ b).reshape(10)

# %%
plt.scatter(X,y)
plt.plot(X,lr.predict(X),color = 'red',label ='OLS')
plt.plot(X,y_pred,color = 'green',label = 'b=0')
plt.legend()

# %%
m= 30.92
b= 100
slope = -2 * np.sum(y -m*X.ravel() - b)
print(slope)
# Out:
# 1899.793876163583

# %%
n=0.01
step_size= n * slope
step_size
# Out:
# 18.99793876163583

# %%
b1 = b- step_size
print(b)
# Out:
# 100

# %%
b1= b- step_size
y_pred1 =   ((30.92 * X) + b1).reshape(10)

plt.scatter(X,y)
plt.plot(X,lr.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.plot(X,y_pred1,color='#00a65a',label='b1 = {}'.format(b1))
plt.legend()
plt.show()

# %%
#iteration2
slope = -2 * np.sum(y -m*X.ravel() - b)
slope
# Out:
# 1899.793876163583

# %%
step_size= n * slope
step_size
# Out:
# 18.99793876163583

# %%
b2= b1- step_size
print(b2)
# Out:
# 62.00412247672835

# %%
y_pred2 =   ((30.92 * X) + b2).reshape(10)

plt.scatter(X,y)
plt.plot(X,lr.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.plot(X,y_pred1,color='#00a65a',label='b1 = {}'.format(b1))
plt.plot(X,y_pred2,color='black',label='b2 = {}'.format(b2))
plt.legend()
plt.show()

# %%
#iteration 3
slope = -2 * np.sum(y -m*X.ravel() - b)
print('slope:',slope)
step_size= n * slope
print('step size',step_size)
b3 = b2- step_size
print(b)
y_pred3 =   ((30.92 * X) + b3).reshape(10)
# Out:
# slope: 1899.793876163583
# step size 18.99793876163583
# 100

# %%
plt.figure(figsize=(15,15))
plt.scatter(X,y)
plt.plot(X,lr.predict(X),color='red',label='OLS')
plt.plot(X,y_pred1,color='#00a65a',label='b1 = {}'.format(b1))
plt.plot(X,y_pred2,color='black',label='b2 = {}'.format(b2))
plt.plot(X,y_pred3,color='blue',label='b3 = {}'.format(b2))
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
#iteration 4
slope = -2 * np.sum(y -m*X.ravel() - b)
print('slope:',slope)
step_size= n * slope
print('step size',step_size)
b4 = b3- step_size
print(b)
y_pred4 =   ((30.92 * X) + b4).reshape(10)
# Out:
# slope: 1899.793876163583
# step size 18.99793876163583
# 100

# %%
#iteration 5
slope = -2 * np.sum(y -m*X.ravel() - b)
print('slope:',slope)
step_size= n * slope
print('step size',step_size)
b5 = b4- step_size
print(b)
y_pred5 =   ((30.92 * X) + b5).reshape(10)
# Out:
# slope: 1899.793876163583
# step size 18.99793876163583
# 100

# %%
plt.figure(figsize=(15,15))
plt.scatter(X,y)
plt.plot(X,lr.predict(X),color='red',label='OLS')
#plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.plot(X,y_pred1,color='#00a65a',label='b1 = {}'.format(b1))
plt.plot(X,y_pred2,color='black',label='b2 = {}'.format(b2))
plt.plot(X,y_pred3,color='blue',label='b3 = {}'.format(b3))
plt.plot(X,y_pred4,color='yellow',label='b4 = {}'.format(b4))
plt.plot(X,y_pred5,color='orange',label='b5 = {}'.format(b5))

plt.legend()
plt.show()

# %%
#iteration 5
slope = -2 * np.sum(y -m*X.ravel() - b)
print('slope:',slope)
step_size= n * slope
print('step size',step_size)
b6 = b5- step_size
print(b)
y_pred6 =   ((30.92 * X) + b6).reshape(10)
# Out:
# slope: 1899.793876163583
# step size 18.99793876163583
# 100

# %%
plt.figure(figsize=(15,15))
plt.scatter(X,y)
plt.plot(X,lr.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.plot(X,y_pred1,color='#00a65a',label='b1 = {}'.format(b1))
plt.plot(X,y_pred2,color='black',label='b2 = {}'.format(b2))
plt.plot(X,y_pred3,color='blue',label='b3 = {}'.format(b3))
plt.plot(X,y_pred4,color='yellow',label='b4 = {}'.format(b4))
plt.plot(X,y_pred5,color='orange',label='b5 = {}'.format(b5))
#plt.plot(X,y_pred6,color='orange',label='b6 = {}'.format(b6))

plt.legend()
plt.show()

# %%
b = 100
m = 30.92
n = 0.01

epochs = 5

for i in range(epochs):
  loss_slope = -2 * np.sum(y - m*X.ravel() - b)
  b = b - (n * slope)
  print(b)

  y_pred = m * X + b

  plt.plot(X,y_pred)

plt.scatter(X,y)
# Out:
# 81.00206123836418
# 62.00412247672835
# 43.00618371509252
# 24.00824495345669
# 5.01030619182086
